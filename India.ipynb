# %%
import pandas as pd
import numpy as np

# %%
pwd!
# Out:
# 'C:\\Users\\Pranay Yenagandula'

# %%
cd Downloads
# Out:
# C:\Users\Pranay Yenagandula\Downloads

# %%
path=r"C:\Users\Pranay Yenagandula\Downloads\owid-covid-data.csv"
df=pd.read_csv(path)

# %%
df
# Out:
#       iso_code  location        date  total_cases  new_cases  total_deaths  \
# 0          ABW     Aruba  2020-03-13            2          2             0
# 1          ABW     Aruba  2020-03-20            4          2             0
# 2          ABW     Aruba  2020-03-24           12          8             0
# 3          ABW     Aruba  2020-03-25           17          5             0
# 4          ABW     Aruba  2020-03-26           19          2             0
# ...        ...       ...         ...          ...        ...           ...
# 11828      ZWE  Zimbabwe  2020-04-15           17          0             3
# 11829      ZWE  Zimbabwe  2020-04-16           23          6             3
# 11830      ZWE  Zimbabwe  2020-04-17           24          1             3
# 11831      ZWE  Zimbabwe  2020-04-18           24          0             3
# 11832      ZWE  Zimbabwe  2020-04-19           25          1             3
#
#        new_deaths  total_cases_per_million  new_cases_per_million  \
# ...

# %%
india = df.iloc[5120:5228]

# %%
india.tail(30)
# Out:
#      iso_code location        date  total_cases  new_cases  total_deaths  \
# 5198      IND    India  2020-03-21          231         40             4
# 5199      IND    India  2020-03-22          320         89             4
# 5200      IND    India  2020-03-23          439        119             7
# 5201      IND    India  2020-03-24          492         53             9
# 5202      IND    India  2020-03-25          562         70             9
# 5203      IND    India  2020-03-26          649         87            13
# 5204      IND    India  2020-03-27          724         75            17
# 5205      IND    India  2020-03-28          873        149            19
# 5206      IND    India  2020-03-29          979        106            25
# 5207      IND    India  2020-03-30         1071         92            29
# 5208      IND    India  2020-03-31         1251        180            32
# 5209      IND    India  2020-04-01         1397        146            35
# ...

# %%
india
# Out:
#      iso_code location        date  total_cases  new_cases  total_deaths  \
# 5120      IND    India  2020-01-02            0          0             0
# 5121      IND    India  2020-01-03            0          0             0
# 5122      IND    India  2020-01-04            0          0             0
# 5123      IND    India  2020-01-05            0          0             0
# 5124      IND    India  2020-01-06            0          0             0
# ...       ...      ...         ...          ...        ...           ...
# 5223      IND    India  2020-04-15        11438       1075           377
# 5224      IND    India  2020-04-16        12380        942           414
# 5225      IND    India  2020-04-17        13387       1007           437
# 5226      IND    India  2020-04-18        14378        991           480
# 5227      IND    India  2020-04-19        15712       1334           507
#
#       new_deaths  total_cases_per_million  new_cases_per_million  \
# ...

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
p1=plt.plot_date(x="date",y="total_cases",data=india3)

# %%
india2 = df.iloc[5180:5228]

# %%
india3 = df.iloc[5200:5228]

# %%
india.to_csv(r"C:\Users\Pranay Yenagandula\Downloads\india.csv")
